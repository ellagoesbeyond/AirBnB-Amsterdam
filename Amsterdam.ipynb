# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

# %%
df = pd.read_csv("/Users/irenewalken/Documents/GitHub/Midterm_project_05.09/archive/listings_details.csv")
df
# Out:
# /var/folders/dc/mkf8yrbx1ds4p7h5pty0xs600000gn/T/ipykernel_30438/4160067243.py:1: DtypeWarning: Columns (87) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/irenewalken/Documents/GitHub/Midterm_project_05.09/archive/listings_details.csv")
#              id                            listing_url       scrape_id  \
# 0          2818      https://www.airbnb.com/rooms/2818  20181206172549
# 1          3209      https://www.airbnb.com/rooms/3209  20181206172549
# 2         20168     https://www.airbnb.com/rooms/20168  20181206172549
# 3         25428     https://www.airbnb.com/rooms/25428  20181206172549
# 4         27886     https://www.airbnb.com/rooms/27886  20181206172549
# ...         ...                                    ...             ...
# 20025  30576148  https://www.airbnb.com/rooms/30576148  20181206172549
# 20026  30577727  https://www.airbnb.com/rooms/30577727  20181206172549
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20030 entries, 0 to 20029
# Data columns (total 96 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                20030 non-null  int64
#  1   listing_url                       20030 non-null  object
#  2   scrape_id                         20030 non-null  int64
#  3   last_scraped                      20030 non-null  object
#  4   name                              19992 non-null  object
#  5   summary                           19510 non-null  object
#  6   space                             14579 non-null  object
#  7   description                       19906 non-null  object
#  8   experiences_offered               20030 non-null  object
#  9   neighborhood_overview             13257 non-null  object
#  10  notes                             9031 non-null   object
# ...

# %%
df["city"].value_counts()
# Out:
# Amsterdam                       19715
# Amsterdam-Zuidoost                193
# Amsterdam Zuid-Oost                35
# Amsterdam                          10
# Badhoevedorp                        9
# Diemen                              8
# De Pijp                             7
# Amstelveen                          7
# Watergraafsmeer                     6
# Duivendrecht                        6
# Jordaan                             5
# Amsterdam (Zunderdorp)              3
# Halfweg                             3
# Amsterdam Zuidoost                  2
# Zeeburg                             2
# Amsterdão                           1
# Ouderkerk aan de Amstel             1
# Buitenveldert                       1
# Weesp                               1
# Zeeburgerkade                       1
# 1015 SN Amsterdam                   1
# Ámsterdam                           1
# Nederland                           1
# Amsterdam, Noord-Holland, NL        1
# Lijnden                             1
# ...

# %%
df["city"] = df["city"].replace(["Amsterdam ","Amsterdam-Zuidoost","Amsterdam Zuid-Oost","De Pijp","Watergraafsmeer", "Jordaan", "Amsterdam (Zunderdorp)", "Amsterdam Zuidoost","Zeeburg","Amsterdão", "Buitenveldert","Zeeburgerkade","1015 SN Amsterdam","Ámsterdam","Amsterdam, Noord-Holland, NL","Amsterdam West","Jordaan, Amsterdam","Амстердам"],["Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam","Amsterdam"])

# %%
df = df[df.city == "Amsterdam"]
df
# Out:
#              id                            listing_url       scrape_id  \
# 0          2818      https://www.airbnb.com/rooms/2818  20181206172549
# 1          3209      https://www.airbnb.com/rooms/3209  20181206172549
# 2         20168     https://www.airbnb.com/rooms/20168  20181206172549
# 3         25428     https://www.airbnb.com/rooms/25428  20181206172549
# 4         27886     https://www.airbnb.com/rooms/27886  20181206172549
# ...         ...                                    ...             ...
# 20025  30576148  https://www.airbnb.com/rooms/30576148  20181206172549
# 20026  30577727  https://www.airbnb.com/rooms/30577727  20181206172549
# 20027  30578037  https://www.airbnb.com/rooms/30578037  20181206172549
# 20028  30579673  https://www.airbnb.com/rooms/30579673  20181206172549
# 20029  30580413  https://www.airbnb.com/rooms/30580413  20181206172549
#
#       last_scraped                                               name  \
# ...

# %%
df["neighbourhood"].value_counts()
# Out:
# Oud-West                               3923
# De Pijp                                1653
# Grachtengordel                         1132
# Bos en Lommer                          1087
# Indische Buurt                          920
# Oosterparkbuurt                         868
# Jordaan                                 860
# Rivierenbuurt                           668
# Oost                                    553
# Hoofddorppleinbuurt                     424
# Watergraafsmeer                         413
# Frederik Hendrikbuurt                   389
# Amsterdam Centrum                       371
# Spaarndammer en Zeeheldenbuurt          349
# Nieuwmarkt en Lastage                   344
# Oud-Zuid                                337
# Stadionbuurt                            313
# Museumkwartier                          298
# Weesperbuurt en Plantage                283
# Slotervaart                             274
# Zeeburg                                 272
# ...

# %%
df["price"].isnull().sum()
# Out:
# 0

# %%
df["neighbourhood"] = df["neighbourhood"].replace(["Nieuwendammerdijk en Buiksloterdijk", "Nieuwendammerham "], ["Nieuwendammerham", "Nieuwendammerham"])
# Out:
# /var/folders/dc/mkf8yrbx1ds4p7h5pty0xs600000gn/T/ipykernel_30438/1343432389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["neighbourhood"] = df["neighbourhood"].replace(["Nieuwendammerdijk en Buiksloterdijk", "Nieuwendammerham "], ["Nieuwendammerham", "Nieuwendammerham"])

# %%
df["price"].value_counts().sort_index()
# Out:
# $0.00          2
# $1,000.00      4
# $1,025.00      1
# $1,050.00      1
# $1,095.00      1
#             ...
# $965.00        1
# $97.00        40
# $98.00        79
# $99.00       465
# $999.00        6
# Name: price, Length: 429, dtype: int64

# %%
np.where(df.price=="$0.00")
# Out:
# (array([13832, 14484]),)

# %%
df = df.drop(index=13842)

# %%
df = df.drop(index=14492)

# %%
df
# Out:
#              id                            listing_url       scrape_id  \
# 0          2818      https://www.airbnb.com/rooms/2818  20181206172549
# 1          3209      https://www.airbnb.com/rooms/3209  20181206172549
# 2         20168     https://www.airbnb.com/rooms/20168  20181206172549
# 3         25428     https://www.airbnb.com/rooms/25428  20181206172549
# 4         27886     https://www.airbnb.com/rooms/27886  20181206172549
# ...         ...                                    ...             ...
# 20025  30576148  https://www.airbnb.com/rooms/30576148  20181206172549
# 20026  30577727  https://www.airbnb.com/rooms/30577727  20181206172549
# 20027  30578037  https://www.airbnb.com/rooms/30578037  20181206172549
# 20028  30579673  https://www.airbnb.com/rooms/30579673  20181206172549
# 20029  30580413  https://www.airbnb.com/rooms/30580413  20181206172549
#
#       last_scraped                                               name  \
# ...

# %%
df.to_csv('/Users/irenewalken/Documents/GitHub/AirBnB-Amsterdam/data/listing_details_new.csv')
